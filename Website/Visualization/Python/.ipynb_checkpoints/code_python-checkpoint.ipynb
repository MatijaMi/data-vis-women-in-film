# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
from itertools import chain

# %%
# Create pandas dataframe from csv
df = pd.read_csv("WFPP_Jobs.csv", sep=",", header=None, names=["ID", "Name", "Pseudonyms", "Link", "Picture", "Jobs", "Lived in", "Born", "Died"])

# %%
# Print a short overview of the dataframe
df.head()
# Out:
#       ID                      Name  \
# 0  21229               Abby Meehan
# 1   1342           Ada Aline Urban
# 2   9728             Emilia Saleny
# 3   1353               Agnes Gavin
# 4  12539  Beatrice Maude Tildesley
#
#                                      Pseudonyms  \
# 0                                           NaN
# 1                   Ada Gorecki|Ada Aline Jones
# 2  Josefina Emilia Saleny|Emilia Saleny Ferrari
# 3            Agnes Kurtz|Agnes Adele Wangenheim
# 4                                           NaN
#
#                                                 Link  \
# 0      https://wfpp.columbia.edu/person/abby-meehan/
# 1  https://wfpp.columbia.edu/person/ada-aline-urban/
# 2  https://wfpp.columbia.edu/person/emilia-saleny-2/
# 3      https://wfpp.columbia.edu/person/agnes-gavin/
# 4  https://wfpp.columbia.edu/person/beatrice-maud...
#
#                                              Picture  \
# 0                                                NaN
# 1  https://wfpp.columbia.edu/wp-content/uploads/2...
# 2  https://wfpp.columbia.edu/wp-content/uploads/2...
# 3                                                NaN
# 4  https://wfpp.columbia.edu/wp-content/uploads/2...
#
#                                                 Jobs               Lived in  \
# 0                                    director|writer                England
# 1                  business partner|company director  England|United States
# 2                          educator|director|actress              Argentina
# 3                                     actress|writer              Australia
# 4  critic|co-founder|secretary|international wome...              Australia
#
#    Born  Died
# 0  1853  1931
# 1  1868  1937
# 2  1894  1978
# 3  1872  1948
# 4  1886  1977

# %%
# Split up Country 1|Country 2|Country 3|... values into multiple rows to properly count the countries each woman lived in
# Don't know exactly what code does, stackoverflow magic
df_countries = (df.set_index(['ID', 'Name', 'Pseudonyms', 'Link', 'Picture', 'Jobs', 'Born', 'Died'])
    .stack()
    .str.split('|', expand=True)
    .stack().unstack(-2)
    .reset_index(-1, drop=True)
    .reset_index())
#df_countries.head()
df_countries.to_csv("df_countries.csv", sep=",")
df_countries=pd.read_csv("df_countries.csv")
df_countries.head()
# Out:
#    Unnamed: 0     ID             Name  \
# 0           0  21229      Abby Meehan
# 1           1   1342  Ada Aline Urban
# 2           2   1342  Ada Aline Urban
# 3           3   9728    Emilia Saleny
# 4           4   1353      Agnes Gavin
#
#                                      Pseudonyms  \
# 0                                           NaN
# 1                   Ada Gorecki|Ada Aline Jones
# 2                   Ada Gorecki|Ada Aline Jones
# 3  Josefina Emilia Saleny|Emilia Saleny Ferrari
# 4            Agnes Kurtz|Agnes Adele Wangenheim
#
#                                                 Link  \
# 0      https://wfpp.columbia.edu/person/abby-meehan/
# 1  https://wfpp.columbia.edu/person/ada-aline-urban/
# 2  https://wfpp.columbia.edu/person/ada-aline-urban/
# 3  https://wfpp.columbia.edu/person/emilia-saleny-2/
# 4      https://wfpp.columbia.edu/person/agnes-gavin/
#
#                                              Picture  \
# 0                                                NaN
# 1  https://wfpp.columbia.edu/wp-content/uploads/2...
# 2  https://wfpp.columbia.edu/wp-content/uploads/2...
# 3  https://wfpp.columbia.edu/wp-content/uploads/2...
# 4                                                NaN
#
#                                 Jobs  Born  Died       Lived in
# 0                    director|writer  1853  1931        England
# 1  business partner|company director  1868  1937        England
# 2  business partner|company director  1868  1937  United States
# 3          educator|director|actress  1894  1978      Argentina
# 4                     actress|writer  1872  1948      Australia

# %%
# Split up Job 1|Job 2|Job 3|... values into multiple rows to properly count the jobs each woman worked in
df_jobs = (df.set_index(['ID', 'Name', 'Pseudonyms', 'Link', 'Picture', 'Lived in', 'Born', 'Died'])
    .stack()
    .str.split('|', expand=True)
    .stack().unstack(-2)
    .reset_index(-1, drop=True)
    .reset_index())
#df_jobs.head()
df_jobs.to_csv("df_jobs.csv", sep=",")
df_jobs=pd.read_csv("df_jobs.csv")
df_jobs.head()
# Out:
#    Unnamed: 0     ID             Name  \
# 0           0  21229      Abby Meehan
# 1           1  21229      Abby Meehan
# 2           2   1342  Ada Aline Urban
# 3           3   1342  Ada Aline Urban
# 4           4   9728    Emilia Saleny
#
#                                      Pseudonyms  \
# 0                                           NaN
# 1                                           NaN
# 2                   Ada Gorecki|Ada Aline Jones
# 3                   Ada Gorecki|Ada Aline Jones
# 4  Josefina Emilia Saleny|Emilia Saleny Ferrari
#
#                                                 Link  \
# 0      https://wfpp.columbia.edu/person/abby-meehan/
# 1      https://wfpp.columbia.edu/person/abby-meehan/
# 2  https://wfpp.columbia.edu/person/ada-aline-urban/
# 3  https://wfpp.columbia.edu/person/ada-aline-urban/
# 4  https://wfpp.columbia.edu/person/emilia-saleny-2/
#
#                                              Picture               Lived in  \
# 0                                                NaN                England
# 1                                                NaN                England
# 2  https://wfpp.columbia.edu/wp-content/uploads/2...  England|United States
# 3  https://wfpp.columbia.edu/wp-content/uploads/2...  England|United States
# 4  https://wfpp.columbia.edu/wp-content/uploads/2...              Argentina
#
#    Born  Died              Jobs
# 0  1853  1931          director
# 1  1853  1931            writer
# 2  1868  1937  business partner
# 3  1868  1937  company director
# 4  1894  1978          educator

# %%
# Group by the countries each person lived in and count it
df_countries_count = df_countries.groupby("Lived in", as_index=False).count()
df_countries_count.to_csv("df_countries_count.csv", sep=",")
df_countries_count=pd.read_csv("df_countries_count.csv")
df_countries_count.head()
# Out:
#    Unnamed: 0   Lived in  Unnamed: 0.1  ID  Name  Pseudonyms  Link  Picture  \
# 0           0  Argentina             1   1     1           1     1        1
# 1           1  Australia            15  15    15          11    15       11
# 2           2    Austria             3   3     3           3     3        2
# 3           3     Brazil             3   3     3           3     3        3
# 4           4     Canada             8   8     8           7     8        7
#
#    Jobs  Born  Died
# 0     1     1     1
# 1    15    15    15
# 2     3     3     3
# 3     3     3     3
# 4     8     8     8

# %%
# Group by the jobs each woman worked in
df_jobs_count = df_jobs.groupby("Jobs", as_index=False).count()
job_mask = (df_jobs_count["ID"] > 4)
df_jobs_count = df_jobs_count[job_mask]
df_jobs_count.to_csv("df_jobs_count.csv", sep=",")
df_countries_count=pd.read_csv("df_jobs_count.csv")
df_jobs_count.head()
# Out:
#                 Jobs  Unnamed: 0   ID  Name  Pseudonyms  Link  Picture  \
# 0         accountant           5    5     5           5     5        4
# 1            actress         160  160   160         136   160      145
# 2            adapter          35   35    35          31    35       30
# 7       art director           6    6     6           5     6        6
# 10  business partner          11   11    11           8    11        6
#
#     Lived in  Born  Died
# 0          5     5     5
# 1        160   160   160
# 2         35    35    35
# 7          6     6     6
# 10        11    11    11

# %%
df_born = df.groupby("Born", as_index=False).count()
born_mask = (df_born["Born"] != 'Unknown' )
df_born = df_born[born_mask]
df_born.to_csv("df_born.csv", sep=",")
df_born.head()
# Out:
#    Born  ID  Name  Pseudonyms  Link  Picture  Jobs  Lived in  Died
# 0  1841   2     2           2     2        1     2         2     2
# 1  1844   1     1           1     1        1     1         1     1
# 2  1848   1     1           1     1        1     1         1     1
# 3  1853   2     2           1     2        1     2         2     2
# 4  1856   1     1           0     1        1     1         1     1

# %%
df_died = df.groupby("Died", as_index=False).count()
died_mask = (df_died["Died"] != 'Unknown' )
df_died = df_died[died_mask]
df_died.to_csv("df_died.csv", sep=",")
df_died.head()
# Out:
#    Died  ID  Name  Pseudonyms  Link  Picture  Jobs  Lived in  Born
# 0  1907   1     1           1     1        0     1         1     1
# 1  1913   1     1           1     1        0     1         1     1
# 2  1917   1     1           1     1        0     1         1     1
# 3  1919   1     1           1     1        1     1         1     1
# 4  1920   3     3           2     3        2     3         3     3

# %%
import numpy as np
import seaborn as sns
df_jobs=pd.read_csv("df_jobs.csv")
uniquevalues = np.unique(df_jobs[['Born']].values)
for Born in uniquevalues:
    df1840_1865 = df_jobs[df_jobs['Born'] < '1865']
    df1840_1865.to_csv("df1840_1865.csv", sep=",")
df1840_1865=pd.read_csv("df1840_1865.csv")
df1840_1865.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     ID          Name  \
# 0           0             0  21229   Abby Meehan
# 1           1             1  21229   Abby Meehan
# 2          43            43   1551  Kate Howarde
# 3          44            44   1551  Kate Howarde
# 4          45            45   1551  Kate Howarde
#
#                                           Pseudonyms  \
# 0                                                NaN
# 1                                                NaN
# 2  Catherine Clarissa Black|Catherine Clarissa Jo...
# 3  Catherine Clarissa Black|Catherine Clarissa Jo...
# 4  Catherine Clarissa Black|Catherine Clarissa Jo...
#
#                                              Link  \
# 0   https://wfpp.columbia.edu/person/abby-meehan/
# 1   https://wfpp.columbia.edu/person/abby-meehan/
# 2  https://wfpp.columbia.edu/person/kate-howarde/
# 3  https://wfpp.columbia.edu/person/kate-howarde/
# 4  https://wfpp.columbia.edu/person/kate-howarde/
#
#                                              Picture  \
# 0                                                NaN
# 1                                                NaN
# 2  https://wfpp.columbia.edu/wp-content/uploads/2...
# 3  https://wfpp.columbia.edu/wp-content/uploads/2...
# 4  https://wfpp.columbia.edu/wp-content/uploads/2...
#
#                               Lived in  Born  Died      Jobs
# 0                              England  1853  1931  director
# 1                              England  1853  1931    writer
# 2  Australia|New Zealand|United States  1864  1939  director
# 3  Australia|New Zealand|United States  1864  1939    writer
# 4  Australia|New Zealand|United States  1864  1939   actress

# %%
sns.jointplot(x='Born',y='Jobs', data=df1840_1865)

# %%
import numpy as np
uniquevalues = np.unique(df_jobs[['Born']].values)
for Born in uniquevalues:
    df1890 = df_jobs[df_jobs['Born'] < '1890' ]
    df1890.to_csv("df1890.csv", sep=",")
df1890=pd.read_csv("df1890.csv")

# %%
uniquevalues = np.unique(df1890[['Born']].values)
for Born in uniquevalues:
    df1865_1890 = df1890[ 1864 < df1890['Born']]
    df1865_1890.to_csv("df1865_1890.csv", sep=",")
df1865_1890=pd.read_csv("df1865_1890.csv")
df1865_1890.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1     ID                      Name  \
# 0           2             2               2   1342           Ada Aline Urban
# 1           3             3               3   1342           Ada Aline Urban
# 2           4             7               7   1353               Agnes Gavin
# 3           5             8               8   1353               Agnes Gavin
# 4           6             9               9  12539  Beatrice Maude Tildesley
#
#                            Pseudonyms  \
# 0         Ada Gorecki|Ada Aline Jones
# 1         Ada Gorecki|Ada Aline Jones
# 2  Agnes Kurtz|Agnes Adele Wangenheim
# 3  Agnes Kurtz|Agnes Adele Wangenheim
# 4                                 NaN
#
#                                                 Link  \
# 0  https://wfpp.columbia.edu/person/ada-aline-urban/
# 1  https://wfpp.columbia.edu/person/ada-aline-urban/
# 2      https://wfpp.columbia.edu/person/agnes-gavin/
# 3      https://wfpp.columbia.edu/person/agnes-gavin/
# 4  https://wfpp.columbia.edu/person/beatrice-maud...
#
#                                              Picture               Lived in  \
# 0  https://wfpp.columbia.edu/wp-content/uploads/2...  England|United States
# 1  https://wfpp.columbia.edu/wp-content/uploads/2...  England|United States
# 2                                                NaN              Australia
# 3                                                NaN              Australia
# 4  https://wfpp.columbia.edu/wp-content/uploads/2...              Australia
#
#    Born  Died              Jobs
# 0  1868  1937  business partner
# 1  1868  1937  company director
# 2  1872  1948           actress
# 3  1872  1948            writer
# 4  1886  1977            critic

# %%
uniquevalues = np.unique(df[['Born']].values)
for Born in uniquevalues:
    df1915 = df[df['Born'] < '1915']
    df1915.to_csv("df1915.csv", sep=",")
df1915=pd.read_csv("df1915.csv")

# %%
uniquevalues = np.unique(df1915[['Born']].values)
for Born in uniquevalues:
    df1890_1915 = df1915[ 1890 < df1915['Born']]
    df1890_1915.to_csv("df1890_1915.csv", sep=",")
df1890_1915=pd.read_csv("df1890_1915.csv")
df1890_1915.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    ID               Name  \
# 0           2             2  9728      Emilia Saleny
# 1           7             7  1592     Mona Donaldson
# 2           8             8  1624  Paulette McDonagh
# 3          10            10  1620    Isabel McDonagh
# 4          11            11  1622   Phyllis McDonagh
#
#                                      Pseudonyms  \
# 0  Josefina Emilia Saleny|Emilia Saleny Ferrari
# 1                                        Miss D
# 2                                           NaN
# 3                                Marie Lorraine
# 4                                           NaN
#
#                                                 Link  \
# 0  https://wfpp.columbia.edu/person/emilia-saleny-2/
# 1   https://wfpp.columbia.edu/person/mona-donaldson/
# 2  https://wfpp.columbia.edu/person/paulette-mcdo...
# 3  https://wfpp.columbia.edu/person/isabel-mcdonagh/
# 4  https://wfpp.columbia.edu/person/phyllis-mcdon...
#
#                                              Picture  \
# 0  https://wfpp.columbia.edu/wp-content/uploads/2...
# 1                                                NaN
# 2  https://wfpp.columbia.edu/wp-content/uploads/2...
# 3  https://wfpp.columbia.edu/wp-content/uploads/2...
# 4  https://wfpp.columbia.edu/wp-content/uploads/2...
#
#                                                 Jobs               Lived in  \
# 0                          educator|director|actress              Argentina
# 1                        booking clerk|censor|editor              Australia
# 2         director|filmmaker|business partner|writer              Australia
# 3                           business partner|actress      Australia|England
# 4  art director|business partner|writer|producer|...  Australia|New Zealand
#
#    Born     Died
# 0  1894     1978
# 1  1901  Unknown
# 2  1901     1978
# 3  1899     1982
# 4  1900     1972

# %%
dfj = pd.read_csv("df_jobs.csv")
df_jobs_filter=dfj[['ID','Jobs']]
df_jobs_filter.to_csv("df_jobs_filter.csv", sep=",")
df_jobs_filter=pd.read_csv("df_jobs_filter.csv")
df_jobs_filter.head()
# Out:
#    Unnamed: 0     ID              Jobs
# 0           0  21229          director
# 1           1  21229            writer
# 2           2   1342  business partner
# 3           3   1342  company director
# 4           4   9728          educator

# %%
dfc = pd.read_csv("df_countries.csv")
df_countries_filter=dfc[['ID','Lived in']]
df_countries_filter.to_csv("df_countries_filter.csv", sep=",")
df_countries_filter=pd.read_csv("df_countries_filter.csv")
df_countries_filter.head()
# Out:
#    Unnamed: 0     ID       Lived in
# 0           0  21229        England
# 1           1   1342        England
# 2           2   1342  United States
# 3           3   9728      Argentina
# 4           4   1353      Australia

# %%
df_jobs_filter_count=df_jobs_filter.groupby("Jobs", as_index=False).count()
job_mask = (df_jobs_filter_count["ID"] > 4)
df_jobs_filter_count = df_jobs_filter_count[job_mask]
df_jobs_filter_count.to_csv("df_jobs_filter_count.csv", sep=",")
df_jobs_filter_count=pd.read_csv("df_jobs_filter_count.csv")
df_jobs_filter_count.head()
# Out:
#    Unnamed: 0              Jobs  Unnamed: 0.1   ID
# 0           0        accountant             5    5
# 1           1           actress           160  160
# 2           2           adapter            35   35
# 3           7      art director             6    6
# 4          10  business partner            11   11

# %%
df_countries_filter_count=df_countries_filter.groupby("Lived in", as_index=False).count()
df_countries_filter_count.to_csv("df_countries_filter_count.csv", sep=",")
df_countries_filter_count=pd.read_csv("df_countries_filter_count.csv")
df_countries_filter_count.head()
# Out:
#    Unnamed: 0   Lived in  Unnamed: 0.1  ID
# 0           0  Argentina             1   1
# 1           1  Australia            15  15
# 2           2    Austria             3   3
# 3           3     Brazil             3   3
# 4           4     Canada             8   8
